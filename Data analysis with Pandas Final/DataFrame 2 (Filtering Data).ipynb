# %% [markdown]
# # Our New Dataset + Memory Optimization

# %%
import pandas as pd

pd.read_csv("employees.csv")
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df = pd.read_csv("employees.csv")

# %%
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df["Start Date"]
# Out:
# 0        8/6/1993
# 1       3/31/1996
# 2       4/23/1993
# 3        3/4/2005
# 4       1/24/1998
#           ...
# 995    11/23/2014
# 996     1/31/1984
# 997     5/20/2013
# 998     4/20/2013
# 999     5/15/2012
# Name: Start Date, Length: 1000, dtype: object

# %%
pd.to_datetime(df["Start Date"])
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1       Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2        Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3        Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4        Larry    Male 1998-01-24         4:47 PM  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23         6:09 AM  132483   16.655
# 996    Phillip    Male 1984-01-31         6:30 AM   42392   19.675
# 997    Russell    Male 2013-05-20        12:39 PM   96914    1.421
# 998      Larry    Male 2013-04-20         4:45 PM   60500   11.985
# 999     Albert    Male 2012-05-15         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])

# %%
df.tail(20)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 980   Kimberly  Female 2013-01-26 2020-07-15 00:57:00   46233    8.862
# 981      James    Male 1993-01-15 2020-07-15 17:19:00  148985   19.280
# 982       Rose  Female 1982-04-06 2020-07-15 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2020-07-15 22:35:00  146907   11.738
# 984      Maria  Female 2011-10-15 2020-07-15 16:53:00   43455   13.040
# 985    Stephen     NaN 1983-07-10 2020-07-15 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2020-07-15 07:04:00   82871   17.999
# 987     Gloria  Female 2014-12-08 2020-07-15 05:08:00  136709   10.331
# 988      Alice  Female 2004-10-05 2020-07-15 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 2020-07-15 16:58:00   38344    3.794
# 990      Robin  Female 1987-07-24 2020-07-15 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-07-15 05:12:00  134505   11.051
# ...

# %%
df["Senior Management"].astype("bool")
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df["First Name"].value_counts()
# Out:
# Marilyn    11
# Barbara    10
# Todd       10
# Jeremy     10
# Cynthia     9
#            ..
# Jean        1
# Brian       1
# Keith       1
# Angela      1
# David       1
# Name: First Name, Length: 200, dtype: int64

# %%
df["Team"] = df["Team"].astype("category")

# %%
df["First Name"] = df["First Name"].astype("object")

# %%
1 - 42.6 / 62.6
# Out:
# 0.31948881789137384

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
#df["Start Date"] = pd.to_datetime(df["Start Date"])
#df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# # Filter DataFrame based on a condition

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
ourWish = df["Gender"] == "Male"

# %%
df[ourWish]

#df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
Finance = df["Team"] == "Finance"

# %%
df[Finance]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2020-07-15 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2020-07-15 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2020-07-15 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2020-07-15 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2020-07-15 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2020-07-15 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2020-07-15 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask2 = df["Senior Management"] == True

# %%
df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2020-07-15 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-07-15 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-07-15 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df["Team"] != "Finance"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
df[df["Team"] != "Finance"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# 8       Angela  Female 2005-11-22 2020-07-15 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask4 = df["Salary"] > 100000

# %%
df[mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-07-15 06:51:00  139852    7.524
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-07-15 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-07-15 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-07-15 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
mask5 = df["Bonus %"] < 1.5

# %%
df[mask5]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2020-07-15 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2020-07-15 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2020-07-15 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2020-07-15 20:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02 2020-07-15 03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03 2020-07-15 16:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12 2020-07-15 20:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08 2020-07-15 19:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19 2020-07-15 01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12 2020-07-15 01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27 2020-07-15 06:40:00   93847    1.085
# ...

# %%
len(df[mask5])
# Out:
# 28

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask6 = df["Start Date"] <= "1990-01-01"

# %%
df[mask6]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-07-15 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2020-07-15 01:08:00  112807   17.492
# 17       Shawn    Male 1986-12-07 2020-07-15 19:45:00  111737    6.414
# ..         ...     ...        ...                 ...     ...      ...
# 983       John    Male 1982-12-23 2020-07-15 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2020-07-15 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2020-07-15 07:04:00   82871   17.999
# 990      Robin  Female 1987-07-24 2020-07-15 13:35:00  100765   10.982
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
#
#      Senior Management             Team
# 5                False            Legal
# ...

# %% [markdown]
# # Filter a DataFrame with more than one condition (AND)

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 & mask2]

# %%
mask2 = df["Team"] == "Marketing"

# %%
df[mask1 & mask2]  # Here logical "and" is represented as "&"
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-07-15 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-07-15 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-07-15 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-07-15 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-07-15 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-07-15 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-07-15 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-07-15 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-07-15 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-07-15 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-07-15 09:45:00   55281    4.935
# ...

# %%
len(df[mask1 & mask2])
# Out:
# 41

# %% [markdown]
# # Filter a DataFrame with more than one condition (OR)

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 | mask2]   # Here logical "or" is represented as "|"
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask3 = df["Senior Management"] == True

# %%
mask4 = df["Start Date"] < "1990-01-01"

# %%
df[mask3 | mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2020-07-15 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-07-15 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df["First Name"].value_counts()
# Out:
# Marilyn    11
# Barbara    10
# Todd       10
# Jeremy     10
# Cynthia     9
#            ..
# Jean        1
# Brian       1
# Keith       1
# Angela      1
# David       1
# Name: First Name, Length: 200, dtype: int64

# %%
mask5 = df["First Name"] == "Jeremy"

# %%
mask6 = df["Team"] == "Engineering"

# %%
mask7 = df["Start Date"] > "2016-01-01"

# %%
df[ (mask5 & mask7) | mask6 ].head(50)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-07-15 06:29:00   95570   18.523
# 30   Christina  Female 2002-08-06 2020-07-15 13:19:00  118780    9.096
# 50       Nancy  Female 2000-09-23 2020-07-15 08:05:00   94976   13.830
# 54        Sara  Female 2007-08-15 2020-07-15 09:23:00   83677    8.999
# 58     Theresa  Female 2010-04-11 2020-07-15 07:18:00   72670    1.481
# 59       Irene  Female 1997-05-07 2020-07-15 09:32:00   66851   11.279
# 113       Tina  Female 2009-06-12 2020-07-15 07:16:00  114767    3.711
# 122  Christina  Female 2012-04-13 2020-07-15 14:04:00  110169   13.892
# 138     Ashley  Female 2006-05-25 2020-07-15 11:30:00  112238    6.030
# 143     Teresa     NaN 2016-01-28 2020-07-15 10:55:00  140013    8.689
# 171    Patrick    Male 2007-08-17 2020-07-15 03:16:00  143499   17.495
# 173    Lillian  Female 2008-12-21 2020-07-15 18:51:00   85446    3.959
# ...

# %% [markdown]
# # Check for inclusion with the isin() Method

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df.head(50)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2020-07-15 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2020-07-15 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2020-07-15 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2020-07-15 09:01:00   63241   15.132
# 11      Julie  Female 1997-10-26 2020-07-15 15:19:00  102508   12.637
# ...

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

# %%
df[mask1 | mask2 | mask3].head(50)
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5         Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# 6           Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# 11         Julie  Female 1997-10-26 2020-07-15 15:19:00  102508   12.637
# 13          Gary    Male 2008-01-27 2020-07-15 23:40:00  109831    5.831
# 15       Lillian  Female 2016-06-05 2020-07-15 06:09:00   59414    1.256
# 17         Shawn    Male 1986-12-07 2020-07-15 19:45:00  111737    6.414
# 19         Donna  Female 2010-07-22 2020-07-15 03:48:00   81014    1.894
# 20          Lois     NaN 1995-04-22 2020-07-15 19:18:00   64714    4.934
# 27         Scott     NaN 1991-07-11 2020-07-15 18:58:00  122367    5.218
# 29      Benjamin    Male 2005-01-26 2020-07-15 22:06:00   79529    7.008
# 31         Joyce     NaN 2005-02-20 2020-07-15 14:40:00   88657   12.752
# 35       Theresa  Female 2006-10-10 2020-07-15 01:12:00   85182   16.675
# ...

# %%
mask8 = df["Team"].isin(["Legal","Sales","Product"])

# %%
mask8 = df["Team"].isin(["Sales","Product","Finance","Engineering"])

# %%
df[mask8]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 6         Ruby  Female 1987-08-17 2020-07-15 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2020-07-15 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2020-07-15 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2020-07-15 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-07-15 15:53:00   56450   19.040
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management         Team
# 2                False      Finance
# 3                 True      Finance
# ...

# %% [markdown]
# # Null Checking with isnull() and notnull() Method

# %%
import pandas as pd

pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
mask1 = df["Team"].isnull() # isnull() return true if the value is NaN(Null)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
df[mask1]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2020-07-15 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2020-07-15 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2020-07-15 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2020-07-15 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2020-07-15 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2020-07-15 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2020-07-15 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2020-07-15 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2020-07-15 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2020-07-15 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2020-07-15 06:06:00   66067   10.957
# ...

# %%
mask1 = df["Team"].isnull()

# %%
mask1 = df["Team"].isnull()
mask2 = df["First Name"].isnull()
mask3 = df["Gender"].isnull()

# %%
mask3 = df["Gender"].isnull()

# %%
df[ mask1 | mask2 | mask3 ]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-07-15 06:53:00   61933    4.170
# 7          NaN  Female 2015-07-20 2020-07-15 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-07-15 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2020-07-15 19:18:00   64714    4.934
# 22      Joshua     NaN 2012-03-08 2020-07-15 01:58:00   90816   18.816
# ..         ...     ...        ...                 ...     ...      ...
# 961    Antonio     NaN 1989-06-18 2020-07-15 21:37:00  103050    3.050
# 972     Victor     NaN 2006-07-28 2020-07-15 14:49:00   76381   11.159
# 985    Stephen     NaN 1983-07-10 2020-07-15 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-07-15 16:58:00   38344    3.794
# 995      Henry     NaN 2014-11-23 2020-07-15 06:09:00  132483   16.655
#
#      Senior Management             Team
# 1                 True              NaN
# ...

# %%
df["Team"].notnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
df[mask4 & mask5 & mask6]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask4 = df["Team"].notnull()
mask5 = df["First Name"].notnull()
mask6 = df["Gender"].notnull()

# %%
df.dropna(how = "any")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-15 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-07-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-15 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-07-15 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-07-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-07-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-15 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# # Check for inclusion within Range of values with the between() Method

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-16 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-16 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-16 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-16 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-16 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-16 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-16 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-16 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-16 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-16 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df["Salary"].between(60000,70000)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998     True
# 999    False
# Name: Salary, Length: 1000, dtype: bool

# %%
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-16 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-07-16 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-07-16 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-07-16 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-07-16 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-07-16 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-07-16 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-07-16 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-07-16 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-07-16 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask1 = df["Salary"].between(60000,70000)

# %%
df[mask1]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-07-16 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2020-07-16 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-07-16 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2020-07-16 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2020-07-16 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2020-07-16 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2020-07-16 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2020-07-16 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2020-07-16 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2020-07-16 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
mask2 = df["Bonus %"].between(2,5)

# %%
df[mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-07-16 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2020-07-16 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2020-07-16 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2020-07-16 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2020-07-16 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2020-07-16 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2020-07-16 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2020-07-16 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2020-07-16 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2020-07-16 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
mask3 = df["Start Date"].between("1990-01-01","1994-03-21")

# %%
df[mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-07-16 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2020-07-16 11:17:00  130590   11.858
# 24        John    Male 1992-07-01 2020-07-16 22:08:00   97950   13.873
# 27       Scott     NaN 1991-07-11 2020-07-16 18:58:00  122367    5.218
# 33        Jean  Female 1993-12-18 2020-07-16 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 940     Andrew    Male 1990-09-28 2020-07-16 09:38:00  137386    8.611
# 959     Albert    Male 1992-09-19 2020-07-16 02:35:00   45094    5.850
# 976     Denise  Female 1992-10-19 2020-07-16 05:42:00  137954    4.195
# 981      James    Male 1993-01-15 2020-07-16 17:19:00  148985   19.280
# 989     Justin     NaN 1991-02-10 2020-07-16 16:58:00   38344    3.794
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask4 = df["Last Login Time"].between("08:00AM","12:00PM")

# %%
df[mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-07-16 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2020-07-16 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-07-16 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2020-07-16 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2020-07-16 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2020-07-16 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2020-07-16 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2020-07-16 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2020-07-16 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2020-07-16 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %% [markdown]
# # Check for duplicate DataFrame Rows with the duplicated() Method

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df.sort_values("First Name", inplace = True)

# %%
df.head(50)

ADAM
ABRAHAM
JOSEPH
JACOB
MOSES
NOAH
GABRIEL
JESUS
DAVID
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-16 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-07-16 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-07-16 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-07-16 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2020-07-16 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2020-07-16 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2020-07-16 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2020-07-16 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2020-07-16 16:20:00   67827   19.717
# ...

# %%
df["First Name"]
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
mask1 = df["First Name"].duplicated()  # duplicated() returns all duplicate values as True except first one

# %%
df[mask1]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2020-07-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-16 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2020-07-16 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-07-16 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-07-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-07-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-07-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-07-16 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-07-16 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
mask2 = df["First Name"].duplicated(keep = "last")  # By Default keep = "first"

# %%
df[mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-16 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2020-07-16 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-07-16 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2020-07-16 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2020-07-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-07-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-07-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-07-16 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
mask3 = df["First Name"].duplicated(keep = False)

# %%
df[mask3].head(20)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-16 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-07-16 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-07-16 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-07-16 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2020-07-16 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2020-07-16 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2020-07-16 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2020-07-16 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2020-07-16 16:20:00   67827   19.717
# ...

# %%
mask4 = ~ df["First Name"].duplicated(keep = False) # '~' sign gives the opposite calculation

# %%
df[mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2020-07-16 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2020-07-16 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2020-07-16 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2020-07-16 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2020-07-16 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2020-07-16 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2020-07-16 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2020-07-16 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2020-07-16 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# # Delete duplicate DataFrame rows with drop_duplicate() Method

# %%
import pandas as pd

df = pd.read_csv("employees.csv", parse_dates = ["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df["Team"] = df["Team"].astype("category")
df.sort_values("First Name", inplace = True)

# %%
df.head(55)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-26 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-26 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-26 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-26 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-07-26 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2020-07-26 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-07-26 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2020-07-26 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2020-07-26 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2020-07-26 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2020-07-26 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2020-07-26 16:20:00   67827   19.717
# ...

# %%
len(df)
# Out:
# 1000

# %%
df.drop_duplicates() # return same as before because don't find any identical row
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-07-16 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2020-07-16 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-07-16 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-07-16 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2020-07-16 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-07-16 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-07-16 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-07-16 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-07-16 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-07-16 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
mask1 = df.drop_duplicates(subset = ["First Name"])

# %%
mask2 = df.drop_duplicates(subset = ["First Name"], keep = "last")

# %%
mask3 = df.drop_duplicates(subset = ["First Name"], keep = False)
