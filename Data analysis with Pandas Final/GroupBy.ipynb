# %% [markdown]
# # Intro to the GroupBy Module

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby('Sector')

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
df.nunique()
# Out:
# Company      996
# Sector        21
# Industry      73
# Location     416
# Revenue      945
# Profits      760
# Employees    755
# dtype: int64

# %%
df.groupby('Sector')

# %%
sectors = df.groupby('Sector')

# %%
sectors

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
type({})
# Out:
# dict

# %% [markdown]
# # First operation with groupby object

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby('Sector')

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
len(df)
# Out:
# 1000

# %%
len(sectors)
# Out:
# 21

# %%
df.Sector.nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
df['Sector'].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Hotels, Resturants & Leisure     25
# Media                            25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Food and Drug Stores             15
# Telecommunications               15
# Apparel                          15
# Name: Sector, dtype: int64

# %%
sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
df.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
sectors.last()
# Out:
#                                                         Company  \
# Sector
# Aerospace & Defense                       Delta Tucker Holdings
# Apparel                                                   Guess
# Business Services                         DeVry Education Group
# Chemicals                                           H.B. Fuller
# Energy                                Portland General Electric
# Engineering & Construction                         MDC Holdings
# Financials                           New York Community Bancorp
# Food and Drug Stores                                     Fred’s
# Food, Beverages & Tobacco            Alliance One International
# Health Care                                  Providence Service
# Hotels, Resturants & Leisure                            Wendy’s
# Household Products                                       Revlon
# Industrials                                   Briggs & Stratton
# ...

# %%
df.tail()
# Out:
#                          Company                        Sector  \
# Rank
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                          Industry       Location  Revenue  Profits  Employees
# Rank
# 996              Commercial Banks   Westbury, NY     1902      -47       3448
# 997   Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 997   Utilities: Gas and Electric   Portland, OR     1898      172       2646
# 999                 Food Services     Dublin, OH     1896      161      21200
# 1000         Industrial Machinery  Wauwatosa, WI     1895       46       5480

# %%
sectors.groups
# returns a dictionary of sector column category which value is the list of specific groupby rows cell
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %%
df.loc[58]
# Out:
# Company                                    FedEx
# Sector                            Transportation
# Industry     Mail, Package, and Freight Delivery
# Location                             Memphis, TN
# Revenue                                    47453
# Profits                                     1050
# Employees                                 323035
# Name: 58, dtype: object

# %% [markdown]
# # Retrieve a group from  a groupby object with the get_group() Method

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby('Sector')

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.get_group('Industrials')
# Out:
#                                   Company       Sector  \
# Rank
# 11                       General Electric  Industrials
# 59                            Caterpillar  Industrials
# 75                Honeywell International  Industrials
# 93                                     3M  Industrials
# 97                                  Deere  Industrials
# 128                      Emerson Electric  Industrials
# 134                             Whirlpool  Industrials
# 148                               Cummins  Industrials
# 211                   Illinois Tool Works  Industrials
# 224                       Parker-Hannifin  Industrials
# 360                                  AGCO  Industrials
# 377                                 Dover  Industrials
# 396                                 Terex  Industrials
# 412                   Rockwell Automation  Industrials
# 419       Harman International Industries  Industrials
# 539                             Flowserve  Industrials
# ...

# %%
sectors.get_group('Energy')
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %%
sectors.get_group('Technology')
# Out:
#                     Company      Sector  \
# Rank
# 3                     Apple  Technology
# 18               Amazon.com  Technology
# 20                       HP  Technology
# 25                Microsoft  Technology
# 31                      IBM  Technology
# ...                     ...         ...
# 970       Rackspace Hosting  Technology
# 971        VeriFone Systems  Technology
# 975    Super Micro Computer  Technology
# 984   Nuance Communications  Technology
# 990             F5 Networks  Technology
#
#                                         Industry         Location  Revenue  \
# Rank
# 3                    Computers, Office Equipment    Cupertino, CA   233715
# 18               Internet Services and Retailing      Seattle, WA   107006
# 20                   Computers, Office Equipment    Palo Alto, CA   103355
# 25                             Computer Software      Redmond, WA    93580
# 31               Information Technology Services       Armonk, NY    82461
# ...

# %%
Sector_is_Technology = df['Sector'] == 'Technology'

# %%
df[Sector_is_Technology]
# Out:
#                     Company      Sector  \
# Rank
# 3                     Apple  Technology
# 18               Amazon.com  Technology
# 20                       HP  Technology
# 25                Microsoft  Technology
# 31                      IBM  Technology
# ...                     ...         ...
# 970       Rackspace Hosting  Technology
# 971        VeriFone Systems  Technology
# 975    Super Micro Computer  Technology
# 984   Nuance Communications  Technology
# 990             F5 Networks  Technology
#
#                                         Industry         Location  Revenue  \
# Rank
# 3                    Computers, Office Equipment    Cupertino, CA   233715
# 18               Internet Services and Retailing      Seattle, WA   107006
# 20                   Computers, Office Equipment    Palo Alto, CA   103355
# 25                             Computer Software      Redmond, WA    93580
# 31               Information Technology Services       Armonk, NY    82461
# ...

# %%
Sector_is_Energy = df['Sector'] == 'Energy'

# %%
df[Sector_is_Energy]
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %% [markdown]
# # Methods on the groupby object and DataFrame column

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby('Sector')

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.max()
# Out:
#                                              Company                Location  \
# Sector
# Aerospace & Defense                         Woodward             Wichita, KS
# Apparel                         Wolverine World Wide       Winston-Salem, NC
# Business Services                      Western Union                Troy, MI
# Chemicals                          Westlake Chemical          Wilmington, DE
# Energy                                   Xcel Energy          Washington, DC
# Engineering & Construction              Tutor Perini         Watsonville, CA
# Financials                            Zions Bancorp.           Worcester, MA
# Food and Drug Stores              Whole Foods Market          Woonsocket, RI
# Food, Beverages & Tobacco            WhiteWave Foods       Winston-Salem, NC
# Health Care                          inVentiv Health                York, PA
# Hotels, Resturants & Leisure              Yum Brands          Wyomissing, PA
# ...

# %%
sectors.min()
# Out:
#                                                     Company  \
# Sector
# Aerospace & Defense                           B/E Aerospace
# Apparel                                            Carter’s
# Business Services                            ABM Industries
# Chemicals                                       A. Schulman
# Energy                                                  AES
# Engineering & Construction                            AECOM
# Financials                                              AIG
# Food and Drug Stores                             CVS Health
# Food, Beverages & Tobacco        Alliance One International
# Health Care                                          AbbVie
# Hotels, Resturants & Leisure                Bloomin’ Brands
# Household Products                            Avon Products
# Industrials                                              3M
# Materials                            A-Mark Precious Metals
# ...

# %%
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.get_group('Technology')['Revenue'].sum()
# Out:
# 1377600

# %%
sectors.get_group('Technology')['Profits'].sum()
# Out:
# 180473

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors[['Revenue','Profits']].sum()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940    28742
# Apparel                         95968     8236
# Business Services              272195    28227
# Chemicals                      243897    22628
# Energy                        1517809   -73447
# Engineering & Construction     153983     5304
# Financials                    2217159   260209
# Food and Drug Stores           483769    16759
# Food, Beverages & Tobacco      555967    51417
# Health Care                   1614707   106114
# Hotels, Resturants & Leisure   169546    20697
# Household Products             234737    14428
# Industrials                    497581    20764
# Materials                      259145     4428
# Media                          220764    24347
# Motor Vehicles & Parts         482540    25898
# Retailing                     1465076    47830
# Technology                    1377600   180473
# Telecommunications             461834    48637
# ...

# %% [markdown]
# # Grouping by Multiple Columns

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby(['Sector','Industry'])

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Advertising, marketing                            0
#                      Aerospace and Defense                            20
#                      Airlines                                          0
#                      Apparel                                           0
#                      Automotive Retailing, Services                    0
#                                                                       ..
# Wholesalers          Waste Management                                  0
#                      Wholesalers: Diversified                         25
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
#                      Wholesalers: Health Care                          0
# Length: 1533, dtype: int64

# %%
sectors.sum()
# Out:
#                                                                     Revenue  \
# Sector              Industry
# Aerospace & Defense Advertising, marketing                              NaN
#                     Aerospace and Defense                          357940.0
#                     Airlines                                            NaN
#                     Apparel                                             NaN
#                     Automotive Retailing, Services                      NaN
# ...                                                                     ...
# Wholesalers         Waste Management                                    NaN
#                     Wholesalers: Diversified                       176138.0
#                     Wholesalers: Electronics and Office Equipment  147906.0
#                     Wholesalers: Food and Grocery                  111774.0
#                     Wholesalers: Health Care                            NaN
#
# ...

# %%
sectors['Revenue'].sum()
# Out:
# Sector               Industry
# Aerospace & Defense  Advertising, marketing                                NaN
#                      Aerospace and Defense                            357940.0
#                      Airlines                                              NaN
#                      Apparel                                               NaN
#                      Automotive Retailing, Services                        NaN
#                                                                         ...
# Wholesalers          Waste Management                                      NaN
#                      Wholesalers: Diversified                         176138.0
#                      Wholesalers: Electronics and Office Equipment    147906.0
#                      Wholesalers: Food and Grocery                    111774.0
#                      Wholesalers: Health Care                              NaN
# Name: Revenue, Length: 1533, dtype: float64

# %% [markdown]
# # The .agg() Method

# %%
import pandas as pd

df = pd.read_csv('fortune1000.csv', index_col = 'Rank')

df.Sector = df.Sector.astype('category')

df.Industry = df.Industry.astype('category')

sectors = df.groupby('Sector')

df
# Out:
#                          Company                        Sector  \
# Rank
# 1                        Walmart                     Retailing
# 2                    Exxon Mobil                        Energy
# 3                          Apple                    Technology
# 4             Berkshire Hathaway                    Financials
# 5                       McKesson                   Health Care
# ...                          ...                           ...
# 996   New York Community Bancorp                    Financials
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# ...

# %%
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors['Employees'].mean()
# Out:
# Sector
# Aerospace & Defense             48402.850000
# Apparel                         23093.133333
# Business Services               26687.254902
# Chemicals                       15455.033333
# Energy                           9745.303279
# Engineering & Construction      15642.615385
# Financials                      24172.287770
# Food and Drug Stores            93026.533333
# Food, Beverages & Tobacco       28177.488372
# Health Care                     35710.520000
# Hotels, Resturants & Leisure    99369.800000
# Household Products              23072.785714
# Industrials                     33591.934783
# Materials                       14840.069767
# Media                           22012.560000
# Motor Vehicles & Parts          45106.666667
# Retailing                       77845.362500
# Technology                      35087.735294
# Telecommunications              55497.866667
# Transportation                  42688.694444
# Wholesalers                     13139.925000
# ...

# %%
sectors['Profits'].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -73447
# Engineering & Construction        5304
# Financials                      260209
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
sectors.agg({'Revenue':'sum',
             'Profits':'sum',
             'Employees':'mean'})
# Out:
#                               Revenue  Profits     Employees
# Sector
# Aerospace & Defense            357940    28742  48402.850000
# Apparel                         95968     8236  23093.133333
# Business Services              272195    28227  26687.254902
# Chemicals                      243897    22628  15455.033333
# Energy                        1517809   -73447   9745.303279
# Engineering & Construction     153983     5304  15642.615385
# Financials                    2217159   260209  24172.287770
# Food and Drug Stores           483769    16759  93026.533333
# Food, Beverages & Tobacco      555967    51417  28177.488372
# Health Care                   1614707   106114  35710.520000
# Hotels, Resturants & Leisure   169546    20697  99369.800000
# Household Products             234737    14428  23072.785714
# Industrials                    497581    20764  33591.934783
# Materials                      259145     4428  14840.069767
# ...

# %%
sectors.agg(['size','sum','mean'])
# Out:
#                              Revenue                        Profits          \
#                                 size      sum          mean    size     sum
# Sector
# Aerospace & Defense               20   357940  17897.000000      20   28742
# Apparel                           15    95968   6397.866667      15    8236
# Business Services                 51   272195   5337.156863      51   28227
# Chemicals                         30   243897   8129.900000      30   22628
# Energy                           122  1517809  12441.057377     122  -73447
# Engineering & Construction        26   153983   5922.423077      26    5304
# Financials                       139  2217159  15950.784173     139  260209
# Food and Drug Stores              15   483769  32251.266667      15   16759
# Food, Beverages & Tobacco         43   555967  12929.465116      43   51417
# Health Care                       75  1614707  21529.426667      75  106114
# ...

# %%
sectors.agg({'Revenue':['sum','mean'],
             'Profits':'sum',
             'Employees':'mean'})
# Out:
#                               Revenue               Profits     Employees
#                                   sum          mean     sum          mean
# Sector
# Aerospace & Defense            357940  17897.000000   28742  48402.850000
# Apparel                         95968   6397.866667    8236  23093.133333
# Business Services              272195   5337.156863   28227  26687.254902
# Chemicals                      243897   8129.900000   22628  15455.033333
# Energy                        1517809  12441.057377  -73447   9745.303279
# Engineering & Construction     153983   5922.423077    5304  15642.615385
# Financials                    2217159  15950.784173  260209  24172.287770
# Food and Drug Stores           483769  32251.266667   16759  93026.533333
# Food, Beverages & Tobacco      555967  12929.465116   51417  28177.488372
# Health Care                   1614707  21529.426667  106114  35710.520000
# Hotels, Resturants & Leisure   169546   6781.840000   20697  99369.800000
# ...

# %% [markdown]
# # PRACTICE

# %% [markdown]
# # Create  a DataFrame from 'fortune1000.csv' and make index with 'Rank' column with set_index() Method and apply each and every method for GroupBy you have learned
